# %%
pip install jcopdl==1.1.10
# Out:
# Collecting jcopdl==1.1.10
#   Downloading jcopdl-1.1.10.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from jcopdl==1.1.10) (2.1.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from jcopdl==1.1.10) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from jcopdl==1.1.10) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from jcopdl==1.1.10) (3.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from jcopdl==1.1.10) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jcopdl==1.1.10) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jcopdl==1.1.10) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jcopdl==1.1.10) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jcopdl==1.1.10) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jcopdl==1.1.10) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jcopdl==1.1.10) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jcopdl==1.1.10) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->jcopdl==1.1.10) (2023.3.post1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->jcopdl==1.1.10) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->jcopdl==1.1.10) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->jcopdl==1.1.10) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->jcopdl==1.1.10) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->jcopdl==1.1.10) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->jcopdl==1.1.10) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->jcopdl==1.1.10) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->jcopdl==1.1.10) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->jcopdl==1.1.10) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->jcopdl==1.1.10) (1.3.0)
# Building wheels for collected packages: jcopdl
#   Building wheel for jcopdl (setup.py) ... done
#   Created wheel for jcopdl: filename=jcopdl-1.1.10-py2.py3-none-any.whl size=17913 sha256=5bccebc28e4f7c7e7b3ea1668b59851c2999d0be2c843827356ab90028b6a56b
#   Stored in directory: /root/.cache/pip/wheels/41/95/30/86345d2446be19c7d97dee789a2597bee81cfbb7b24a847f7c
# Successfully built jcopdl
# Installing collected packages: jcopdl
# Successfully installed jcopdl-1.1.10

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import jcopdl
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn, optim
from jcopdl.callback import Callback, set_config

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# %%
#define trasnforms
bs = 64
crop_size = 224

train_transform = transforms.Compose([
    transforms.RandomRotation(10),
    transforms.RandomResizedCrop(crop_size,scale=(0.7, 1)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize(227),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

#load the dataset
train_set = datasets.ImageFolder("/content/drive/MyDrive/Colab Notebooks/Genus_ikan", transform=train_transform)
trainloader = DataLoader(train_set, batch_size=bs, shuffle=True)

val_set = datasets.ImageFolder("/content/drive/MyDrive/Colab Notebooks/Genus_ikan", transform=val_transform)
valloader = DataLoader(val_set, batch_size=bs, shuffle=True)

# %%
label2cat = train_set.classes
label2cat
# Out:
# ['Aluterus',
#  'Anampses',
#  'Bodianus',
#  'Cantherhines',
#  'Caranggoides',
#  'Carcharhinus',
#  'Cephalopholis',
#  'Cheilinus',
#  'Cirrhilabrus',
#  'Coris',
#  'Epinephelus',
#  'Halicholes',
#  'Lethrinus',
#  'Lutjanus',
#  'Machropharyo',
#  'Meuchenia',
#  'Oxycheilinus',
#  'Pervagor',
#  'Plectropomus',
#  'Pristipomoides',
#  'Pseudanthias',
#  'Pseudocheilinus',
#  'Scolopsis',
#  'Stethojulis',
#  'Thalassoma']

# %%
# Load arsitektur VGG16 dan Freeze weights
from torch.nn.modules import dropout
from torchvision.models import vgg16
mnet = vgg16(pretrained=True)
for param in mnet.parameters():
    param.requires_grad = False

# Configurasi Arsitektur VGG16 (Fully Connected Layer)
mnet.classifier = nn.Sequential(
    nn.Linear(25088, 4096),
    nn.ReLU(True),
    nn.Dropout(0.5),
    nn.Linear(4096, 4096),
    nn.ReLU(True),
    nn.Dropout(0.5),
    nn.Linear(4096, 6)
)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:03<00:00, 150MB/s]

# %%
mnet
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=6, bias=True)
#   )
# )

# %%
class Customvgg16(nn.Module):
    def __init__(self, output_size):
        super().__init__()
        self.mnet = vgg16(pretrained=True)
        self.freeze()
        self.mnet.classifier = nn.Sequential(
                nn.Linear(25088, 4096),
                nn.ReLU(True),
                nn.Dropout(0.5),
                nn.Linear(4096, 4096),
                nn.ReLU(True),
                nn.Dropout(0.5),
                nn.Linear(4096, output_size)
            )

    def forward(self, x):
        return self.mnet(x)
    def freeze(self):
        for param in self.mnet.parameters():
            param.requires_grad = False
    def unfreeze(self):
        for param in self.mnet.parameters():
            param.requires_grad = True

# %%
config = set_config({
    "output_size": len(train_set.classes),
    "batch_size" : bs,
    "crop_size" : crop_size
})

# %%
model = Customvgg16(config.output_size).to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.001)

# %%
def loop_fn(mode, dataset, dataloader, model, criterion, optimizer, device):
    if mode == "train":
        model.train()
    elif mode == "val":
        model.eval()
    cost = correct = 0
    # Move tensors to the configured device
    for feature, target in dataloader:
        feature, target = feature.to(device), target.to(device)
        # Forward pass
        output = model(feature)
        loss = criterion(output, target)
        # Backward and optimize
        if mode == "train":
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        cost += loss.item() * feature.shape[0]
        correct += (output.argmax(1) == target).sum().item()
    cost = cost / len(dataset)
    acc = correct / len(dataset)
    return cost, acc

# %%
#Validation
epochs = 15
train_cost, val_cost = [], []
train_acc, val_acc = [], []
for i in range (epochs):
  cost, acc = loop_fn("train", train_set, trainloader, model, criterion, optimizer, device)
  train_cost.append(cost)
  train_acc.append(acc)
  with torch.no_grad():
      cost, acc = loop_fn("val", val_set, valloader, model, criterion, optimizer, device)
      val_cost.append(cost)
      val_acc.append(acc)
  print(f"Epoch: {i+1}/{epochs} | train_cost: {train_cost[-1]:.4f} | val_cost: {val_cost[-1]:.4f} | "
        f" train_acc: {train_acc[-1]:.4f} | val_acc: {val_acc[-1]:.4f}")
# Out:
# Epoch: 1/15 | train_cost: 3.9995 | val_cost: 1.3659 |  train_acc: 0.3271 | val_acc: 0.6034
# Epoch: 2/15 | train_cost: 1.5220 | val_cost: 1.0200 |  train_acc: 0.5435 | val_acc: 0.6753
# Epoch: 3/15 | train_cost: 1.2374 | val_cost: 0.7184 |  train_acc: 0.6185 | val_acc: 0.7868
# Epoch: 4/15 | train_cost: 1.0837 | val_cost: 0.6165 |  train_acc: 0.6681 | val_acc: 0.8087
# Epoch: 5/15 | train_cost: 0.9683 | val_cost: 0.6748 |  train_acc: 0.7146 | val_acc: 0.7884
# Epoch: 6/15 | train_cost: 0.9898 | val_cost: 0.4294 |  train_acc: 0.7237 | val_acc: 0.8714
# Epoch: 7/15 | train_cost: 0.9846 | val_cost: 0.4166 |  train_acc: 0.7225 | val_acc: 0.8718
# Epoch: 8/15 | train_cost: 0.9343 | val_cost: 0.4747 |  train_acc: 0.7408 | val_acc: 0.8507
# Epoch: 9/15 | train_cost: 0.8951 | val_cost: 0.4853 |  train_acc: 0.7638 | val_acc: 0.8460
# Epoch: 10/15 | train_cost: 0.8235 | val_cost: 0.3903 |  train_acc: 0.7868 | val_acc: 0.8785
# Epoch: 11/15 | train_cost: 0.8052 | val_cost: 0.4012 |  train_acc: 0.7936 | val_acc: 0.8857
# Epoch: 12/15 | train_cost: 0.8291 | val_cost: 0.3081 |  train_acc: 0.7848 | val_acc: 0.9146
# Epoch: 13/15 | train_cost: 0.8391 | val_cost: 0.3154 |  train_acc: 0.7912 | val_acc: 0.9099
# Epoch: 14/15 | train_cost: 0.8694 | val_cost: 0.4679 |  train_acc: 0.7829 | val_acc: 0.8634
# Epoch: 15/15 | train_cost: 0.8740 | val_cost: 0.3098 |  train_acc: 0.7892 | val_acc: 0.9150

# %%
#Plotting
plt.figure(figsize=(15, 5))

plt.subplot(121)
plt.plot(train_cost, 'r-', label='Train')
plt.plot(val_cost, 'b-', label='Val')
plt.xlabel("epoch"); plt.ylabel("cost"); plt.legend();

plt.subplot(122)
plt.plot(train_acc, 'r-', label='Train')
plt.plot(val_acc, 'b-', label='Val')
plt.xlabel("epoch"); plt.ylabel("acccuracy"); plt.legend();

# %%
#unfreeze weights
model.unfreeze()
optimizer = optim.AdamW(model.parameters(), lr=1e-5)

# %%
#validation
epochs = 20
train_cost, val_cost = [], []
train_acc, val_acc = [], []
for i in range (epochs):
  cost, acc = loop_fn("train", train_set, trainloader, model, criterion, optimizer, device)
  train_cost.append(cost)
  train_acc.append(acc)
  with torch.no_grad():
      cost, acc = loop_fn("val", val_set, valloader, model, criterion, optimizer, device)
      val_cost.append(cost)
      val_acc.append(acc)
  print(f"Epoch: {i+1}/{epochs} | train_cost: {train_cost[-1]:.4f} | val_cost: {val_cost[-1]:.4f} | "
        f" train_acc: {train_acc[-1]:.4f} | val_acc: {val_acc[-1]:.4f}")
# Out:
# Epoch: 1/20 | train_cost: 0.5921 | val_cost: 0.2986 |  train_acc: 0.8408 | val_acc: 0.9377
# Epoch: 2/20 | train_cost: 0.5173 | val_cost: 0.2816 |  train_acc: 0.8507 | val_acc: 0.9408
# Epoch: 3/20 | train_cost: 0.4624 | val_cost: 0.2584 |  train_acc: 0.8698 | val_acc: 0.9452
# Epoch: 4/20 | train_cost: 0.4155 | val_cost: 0.2234 |  train_acc: 0.8722 | val_acc: 0.9520
# Epoch: 5/20 | train_cost: 0.4246 | val_cost: 0.2392 |  train_acc: 0.8841 | val_acc: 0.9575
# Epoch: 6/20 | train_cost: 0.3648 | val_cost: 0.2248 |  train_acc: 0.8960 | val_acc: 0.9559
# Epoch: 7/20 | train_cost: 0.3283 | val_cost: 0.1818 |  train_acc: 0.8976 | val_acc: 0.9635
# Epoch: 8/20 | train_cost: 0.3016 | val_cost: 0.1699 |  train_acc: 0.9075 | val_acc: 0.9674
# Epoch: 9/20 | train_cost: 0.3238 | val_cost: 0.1725 |  train_acc: 0.9047 | val_acc: 0.9667
# Epoch: 10/20 | train_cost: 0.2880 | val_cost: 0.1804 |  train_acc: 0.9123 | val_acc: 0.9643
# Epoch: 11/20 | train_cost: 0.2835 | val_cost: 0.1656 |  train_acc: 0.9190 | val_acc: 0.9667
# Epoch: 12/20 | train_cost: 0.2671 | val_cost: 0.1435 |  train_acc: 0.9166 | val_acc: 0.9694
# Epoch: 13/20 | train_cost: 0.2676 | val_cost: 0.1674 |  train_acc: 0.9186 | val_acc: 0.9667
# Epoch: 14/20 | train_cost: 0.2156 | val_cost: 0.1263 |  train_acc: 0.9325 | val_acc: 0.9714
# Epoch: 15/20 | train_cost: 0.2377 | val_cost: 0.1259 |  train_acc: 0.9250 | val_acc: 0.9762
# Epoch: 16/20 | train_cost: 0.2108 | val_cost: 0.1261 |  train_acc: 0.9353 | val_acc: 0.9758
# Epoch: 17/20 | train_cost: 0.2068 | val_cost: 0.1122 |  train_acc: 0.9393 | val_acc: 0.9766
# Epoch: 18/20 | train_cost: 0.2080 | val_cost: 0.1178 |  train_acc: 0.9353 | val_acc: 0.9734
# Epoch: 19/20 | train_cost: 0.2081 | val_cost: 0.1007 |  train_acc: 0.9337 | val_acc: 0.9790
# Epoch: 20/20 | train_cost: 0.1755 | val_cost: 0.1016 |  train_acc: 0.9444 | val_acc: 0.9774

# %%
#Plotting
plt.figure(figsize=(15, 5))

plt.subplot(121)
plt.plot(train_cost, 'r-', label='Train')
plt.plot(val_cost, 'b-', label='Val')
plt.xlabel("epoch"); plt.ylabel("cost"); plt.legend();

plt.subplot(122)
plt.plot(train_acc, 'r-', label='Train')
plt.plot(val_acc, 'b-', label='Val')
plt.xlabel("epoch"); plt.ylabel("acccuracy"); plt.legend();

# %%
feature, target = next(iter(valloader))
feature, target = feature.to(device), target.to(device)

# %%
with torch.no_grad():
    model.eval()
    output = model(feature)
    preds = output.argmax(1)
preds
# Out:
# tensor([ 8, 15, 13,  6, 10,  7, 10, 13, 11, 11, 13, 13, 20, 20, 11, 15, 10, 19,
#          5,  4,  6, 20,  0, 11, 11, 24,  4, 24, 13,  8, 10, 11, 20, 21,  5,  8,
#         24,  9, 24, 20,  2, 10,  6, 20, 13,  2, 11, 14,  5, 10, 10, 13, 24,  5,
#          4, 13, 10,  4,  9, 13, 10,  6, 10, 13], device='cuda:0')

# %%
#inverse Images
def inverse_norm(img):
    img[0, :, :] = img[0, :, :] = 0.229 + 0.485
    img[1, :, :] = img[1, :, :] = 0.224 + 0.456
    img[2, :, :] = img[2, :, :] = 0.225 + 0.406
    return img

# %%
#plot images hasil prediksi
fig, axes = plt.subplots(6, 6, figsize=(24, 24))
for image, label, pred, ax in zip(feature, target, preds, axes.flatten()):
    ax.imshow(image.permute(1, 2, 0).cpu())
    font = {"color": 'r'} if label != pred else {"color": 'g'}
    label, pred =label2cat[label.item()], label2cat[pred.item()]
    ax.set_title(f"L: {label} | p: {pred}", fontdict=font);
    ax.axis('off');
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
torch.save(model.state_dict(), '/content/drive/MyDrive/Colab Notebooks/Model/model.pth')
